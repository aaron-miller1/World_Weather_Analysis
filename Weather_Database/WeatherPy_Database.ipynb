# %%
# Import dependencies
import random
import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

# %%
from citipy import citipy

# import requests library

import requests

# import API key

from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random lats and longs combo

lats = np.random.uniform(-90.000,90.000,size=2000)

longs = np.random.uniform(-180.000,180.000, size=2000)

lat_longs = zip(lats, longs)

coordinates = list(lat_longs)

# %%
import time

from datetime import datetime

# %%
# create a list for holding cities

cities = []

# identify nearest city for each lat and long combo

for coordinate in coordinates:
    
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
#     if the city is unique, add to cities list
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 736

# %%
      
# create empty list for weather data

city_data = []

# print beginning of the logging

print('Beginning Data Retrieval    ')

print('----------------------------')


# create counters

record_count = 1

set_count = 1

# Loop through all the cities in the list

for i, city in enumerate(cities):
    
    
#     Group cities in sets of 50 for logging purposes

    if (i % 50 == 0 and i >= 50):
        
        set_count += 1
        
        record_count = 1
        
        time.sleep(60)
        
#         Create endpoint url
    city_url = url + '&q=' + city.replace(" ","+")
    
#     log the url
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    
#     add 1 to the record count

    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | bethel
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | alice springs
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | airai
# Processing Record 6 of Set 1 | sorong
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | saskylakh
# Processing Record 9 of Set 1 | palapye
# Processing Record 10 of Set 1 | milkovo
# Processing Record 11 of Set 1 | rawson
# Processing Record 12 of Set 1 | upernavik
# Processing Record 13 of Set 1 | mattru
# Processing Record 14 of Set 1 | trincomalee
# Processing Record 15 of Set 1 | mar del plata
# Processing Record 16 of Set 1 | khasan
# Processing Record 17 of Set 1 | georgetown
# Processing Record 18 of Set 1 | bereda
# Processing Record 19 of Set 1 | narsaq
# Processing Record 20 of Set 1 | bengkulu
# Processing Record 21 of Set 1 | geraldton
# Processing Record 22 of Set 1 | ponta do sol
# ...

# %%
city_data_df = pd.DataFrame(city_data)

city_data_df
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Bethel  41.3712  -73.4140     69.64        85         100
# 1            Ushuaia -54.8000  -68.3000     38.23        91          36
# 2      Alice Springs -23.7000  133.8833     69.22        32          75
# 3             Albany  42.6001  -73.9662     74.62        71          98
# 4              Airai  -8.9266  125.4092     66.67        83          64
# ..               ...      ...       ...       ...       ...         ...
# 665             Inta  66.0317   60.1659     45.01        87          39
# 666  Charters Towers -20.1000  146.2667     74.01        45           0
# 667          Sorland  67.6670   12.6934     42.66        90          37
# 668          Talnakh  69.4865   88.3972     35.38       100         100
# 669      Yerbogachen  61.2767  108.0108     56.14        54          15
#
#      Wind Speed Country                 Date Current Description
# ...

# %%
# city_data_df = city_data_df.reindex(columns=['City', 'Country','Lat','Lng','Max Temp', 'Humidity','Cloudiness','Wind Speed','Current Description', 'Date'])

city_data_df = city_data_df.drop(columns = ['Date'])

city_data_df
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Bethel      US  41.3712  -73.4140     69.64        85
# 1            Ushuaia      AR -54.8000  -68.3000     38.23        91
# 2      Alice Springs      AU -23.7000  133.8833     69.22        32
# 3             Albany      US  42.6001  -73.9662     74.62        71
# 4              Airai      TL  -8.9266  125.4092     66.67        83
# ..               ...     ...      ...       ...       ...       ...
# 665             Inta      RU  66.0317   60.1659     45.01        87
# 666  Charters Towers      AU -20.1000  146.2667     74.01        45
# 667          Sorland      NO  67.6670   12.6934     42.66        90
# 668          Talnakh      RU  69.4865   88.3972     35.38       100
# 669      Yerbogachen      RU  61.2767  108.0108     56.14        54
#
#      Cloudiness  Wind Speed Current Description
# 0           100        5.99     overcast clouds
# 1            36        5.03    scattered clouds
# ...

# %%
city_data_df.to_csv('../World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv', index=False)
